# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import math

# %%
df = pd.read_excel('C:/Users/Administrator/Desktop/misis_practice/orders_2023.xlsx')
df.head(5)
# Out:
#                                                 ости  \
# 0  ФАКТОР НАСЛЕДСТВЕННОЙ ТРОМБОФИЛИИ У ПАЦИЕНТОК ...
# 1  ОПЫТ ИСПОЛЬЗОВАНИЯ МЕТОДИК ТЕРОПЕВТИЧЕСКОЙ РЕК...
# 2  Сравнительная характеристика Нр-позитивного и ...
# 3  Современные подходы к лечению постравматически...
# 4      Современные аспекты диагностики и лечения ВМД
#
#                                        Авторы работы  \
# 0  Гасанова Сабина Мубаризовна, аспирант кафедры ...
# 1  Жучков М.М. студент 6 курса,10 группы, педиатр...
# 2  Кузнецова Евгения Александровна, студентка 10 ...
# 3        Евстигнеева А.А, ординатор, ФГБОУ ВО ИвГМА.
# 4  Федотовская Арина Сергеевна, ординатор, ФГБОУ ...
#
#           Название представляющей организации, город  \
# 0  ФГБУ "Ивановский научно-исследовательский инст...
# 1  ФГБОУ ВО «Ивановская государственная медицинск...
# 2  ФГБОУ ВО "Ивановская государственная медицинск...
# 3                               ФГБОУ ВО ИвГМА МЗ РФ
# ...

# %%
df['Направление работы конференции'].value_counts()[df['Направление работы конференции'][2]]
# Out:
# 9

# %%
len(df['Направление работы конференции'].value_counts())
# Out:
# 27

# %%
df_size = len(df) 
prop_list = {}
for i in df['Направление работы конференции'].unique():
    prop_list[i] = df['Направление работы конференции'].value_counts()[i] / df_size

# %%
df['Направление работы конференции'].value_counts().values.mean()
# Out:
# 7.592592592592593

# %%
df['Направление работы конференции'].value_counts().plot(kind='bar', title='Count (target)')
# Out:
# <AxesSubplot:title={'center':'Count (target)'}>

# %%
target_count = df.target.value_counts()
print('Class 0:', target_count[0])
print('Class 1:', target_count[1])
print('Proportion:', round(target_count[0] / target_count[1], 2), ': 1')

colors = ['red', 'green']

target_count.plot(kind='bar', title='Count (target)', color = colors);
